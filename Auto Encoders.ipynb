# %% [markdown]
# This notebook is a guided project for **AutoEncoders**.
#
# The Notebook is designed in a "*fill-in-the-blank*" way.
#
# Therefore its required to fill in the "____" fields with the necessary code to run the notebook.

# %% [markdown]
# **bold text**# Introduction

# %% [markdown]
# **AutoEncoders** are a type of neural network that is mainly designed with the goal of learning low-dimensional representations or **latent features** of a given dataset such that those representations can be used to **reconstruct** the original data.
#
# For such goal, these neural networks are structured as follows:
#
# 1. An **encoder network** : This network is used to learn a low-dimensional representation of the input data.
#
# 2. A **decoder network** : This network is used to reconstruct the input data from the low-dimensional representation.
#
# 3. A **loss function**: This function is used to quantify the difference between the reconstructed data and the original data.
#
# The network then combines the encoder and decoder networks and starts training to minimize the loss function by learning the optimal low-dimensional representation then reconstructing it to the original data.
#
# Once we reach the desired loss and the reconstructed data is close enough to the original data, this would indicate that those low-dimensional representations learned are good enough to represent the original data. We can then say we reached the latent features level of the data.
#
# <br>
# <br>
#
# <p align="center">
#   <img src="https://media.springernature.com/lw685/springer-static/image/chp%3A10.1007%2F978-1-4842-8020-1_9/MediaObjects/463356_2_En_9_Fig1_HTML.jpg" />
# </p>

# %% [markdown]
# # Enabling the GPU
#
# It is advisable to enable GPU as it will speed up the training process considerably compared to CPU.
#
# To Enable the GPU:
#
# > Go to Runtime --> Change runtime type --> Hardware Accelerator --> Select GPU.

# %% [markdown]
# Test if GPU is enabled

# %%
import tensorflow as tf

if tf.config.list_physical_devices('GPU'):
    print("GPU is available")
    print(tf.config.list_physical_devices('GPU'))
else:
    print("WARNING: No GPU available!")
# Out:
# GPU is available
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Installations and Imports

# %% [markdown]
# Do the necessary installations

# %%
# !pip install visualkeras  -q
# !pip install gdown
# !gdown 1tKSnNdRQ8LnRFkcc-LPEV6sI0drwHK-Y
# !tar -xvf ArabicMNISTDataset.tar.gz
# !rm ArabicMNISTDataset.tar.gz
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.4/997.4 kB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.17.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=1tKSnNdRQ8LnRFkcc-LPEV6sI0drwHK-Y
# To: /content/ArabicMNISTDataset.tar.gz
# 100% 21.3M/21.3M [00:00<00:00, 50.0MB/s]
# ArabicMNISTDataset.mat

# %% [markdown]
# Import the necessary libraries.

# %%
import keras
from keras import layers
import numpy as np
import pandas as pd
import visualkeras
import os
from scipy.io import loadmat
import matplotlib.pyplot as plt
import cv2
import random
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')

# Seed the environment
def seed_my_session(seed=16):
  random.seed(seed)
  np.random.seed(seed)
  tf.random.set_seed(seed)
  os.environ['PYTHONHASHSEED'] = str(seed)
seed_my_session()

# Define some colors for visualizations later
color_map = defaultdict(dict)
color_map[layers.InputLayer]['fill'] = '#f58442'
color_map[layers.Conv2D]['fill'] = '#85e079'
color_map[layers.MaxPooling2D]['fill'] = '#d9f2bd'
color_map[layers.Flatten]['fill'] = '#8b848c'
color_map[layers.Dense]['fill'] = '#545354'
color_map[layers.UpSampling2D]['fill'] = '#79c7b1'
color_map[layers.BatchNormalization]['fill'] = '#bc81cc'
color_map[layers.Reshape]['fill'] = '#b4adba'

# %% [markdown]
# Create a utility function to display the images to visualize our model's performance later (original VS reconstructed images).

# %%
def display_digits(original_images, reconstructed_images, digits=10):
    # Create a figure with 2 rows and columns set to digits for image-vs-image plots
    fig, axes = plt.subplots(2, digits, figsize=(20, 4))
    fig.suptitle('Original Vs Reconstructed Images', fontsize=14, fontweight='bold')
    # Get the axes
    axes = axes.flatten()
    # Display the original and reconstructed images.
    for i in range(digits):
        # Reshape the image from (3600) 1D array to (60,60) 2D array
        original_image = original_images[i].reshape(60, 60)
        # Display original image.
        axes[i].imshow(original_image, cmap='gray')
        axes[i].axis('off')
        # Reshape the image from (3600) 1D array to (60,60) 2D array
        reconstructed_image = reconstructed_images[i].reshape(60, 60)
        # Display reconstructed image below the original one
        axes[i + digits].imshow(reconstructed_image, cmap='gray')
        axes[i + digits].axis('off')
    # Show the figure.
    plt.show()

# %% [markdown]
# # Data Preparation

# %% [markdown]
# Now Lets Start preparing our Arabic Mnist Dataset
#
# The data was installed as ArabicDataset.mat file
#
#
#
# <p align="center">
#   <img src="https://raw.githubusercontent.com/mohamadmansourX/AutoEncoders/main/doc/datagrid.png" />
# </p>

# %%
data_path = 'ArabicMNISTDataset.mat'

# Load the dataset using the data_path
dataset = loadmat(data_path)

# The dataset is stored in a dictionary of train and test data.
x_train = dataset['x_train']
x_test = dataset['x_test']

# Change the dtype of x_train and x_test to float.
x_train = x_train.astype('float32')
x_test =x_test.astype('float32')

# We can check its shape
print(x_train.shape)
print(x_test.shape)
# Out:
# (13439, 3600)
# (3359, 3600)

# %% [markdown]
# Lets visualize the dataset.

# %%
# We will display 5x5 random images from the training dataset
# Get a sample of 25 random images.
sample_images = random.sample(list(x_train), 25)
# Prepare the plot
plt.figure(figsize=(10,10))
# Set a title for the figure.
plt.suptitle('Random Images from the Training Dataset', fontsize=24, fontweight='bold')

for i in range(25):
    # Set the place holder to the current image.
    plt.subplot(5, 5, i+1)
    # Reshape sample_images from 1D (3600) to 2D (60,60)
    sample_image = sample_images[i].reshape(60, 60)
    # Display the current image.
    plt.imshow(sample_image, cmap='gray')
    plt.axis('off')

# %% [markdown]
# # Building the AutoEncoder

# %% [markdown]
# ## Simple ANN AutoEncoder

# %%
# Building a simple autoencoder

# Set the bottleneck_size to be 81.
bottleneck_size = 81

# Create the input layer having the shape of the training data = 3600
input_layer = keras.layers.Input(shape=(3600,))

# Create the encoder having the neurons set to the bottleneck_size and activate to 'relu'
encoded = keras.layers.Dense(bottleneck_size, activation='relu')(input_layer)

# Let's not forget the Batch Normalization layer.
x = layers.BatchNormalization()(encoded)

# Create the decoder having the output shape equal to the input shape = 3600 and the activation set to 'sigmoid'
decoded = keras.layers.Dense(3600, activation='sigmoid')(x)

# Create the autoencoder.
autoencoder = keras.models.Model(input_layer, decoded)

# Compile the autoencoder using 'adam' as the optimizer and the 'binary_crossentropy' loss.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Print the summary of the autoencoder.
autoencoder.summary()

# Visualize the model
visualkeras.layered_view(autoencoder, legend=True,  draw_volume=True, spacing= 10, color_map= color_map)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 3600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 81)                  │         291,681 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 81)                  │             324 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3600)                │         295,200 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 587,205 (2.24 MB)
#  Trainable params: 587,043 (2.24 MB)
#  Non-trainable params: 162 (648.00 B)
# <PIL.Image.Image image mode=RGBA size=817x65>

# %% [markdown]
# Note the input data (training data usually denoted by X) and the output data (target data usually denoted by Y) **are the same data** as we are learning to reconstruct the data.

# %%
# Fit the autoencoder to the training data by setting epochs to 60 and batch size to 128.
# Both the input and output are the same data
autoencoder.fit(x_train, x_train,
                epochs=60,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.6441 - val_loss: 0.3526
# Epoch 2/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2293 - val_loss: 0.1331
# Epoch 3/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1199 - val_loss: 0.1060
# Epoch 4/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1034 - val_loss: 0.0991
# Epoch 5/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0952 - val_loss: 0.0913
# Epoch 6/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0899 - val_loss: 0.0880
# Epoch 7/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0860 - val_loss: 0.0854
# Epoch 8/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0839 - val_loss: 0.0826
# Epoch 9/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0818 - val_loss: 0.0812
# Epoch 10/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0805 - val_loss: 0.0800
# Epoch 11/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0794 - val_loss: 0.0791
# Epoch 12/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0786 - val_loss: 0.0787
# Epoch 13/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0778 - val_loss: 0.0783
# Epoch 14/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0777 - val_loss: 0.0781
# Epoch 15/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0772 - val_loss: 0.0780
# Epoch 16/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0768 - val_loss: 0.0776
# Epoch 17/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0765 - val_loss: 0.0771
# Epoch 18/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0763 - val_loss: 0.0768
# Epoch 19/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0760 - val_loss: 0.0767
# Epoch 20/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0758 - val_loss: 0.0765
# Epoch 21/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0756 - val_loss: 0.0764
# Epoch 22/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0755 - val_loss: 0.0763
# Epoch 23/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0754 - val_loss: 0.0763
# Epoch 24/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0754 - val_loss: 0.0763
# Epoch 25/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0753 - val_loss: 0.0764
# Epoch 26/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0753 - val_loss: 0.0763
# Epoch 27/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0752 - val_loss: 0.0764
# Epoch 28/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0752 - val_loss: 0.0762
# Epoch 29/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0751 - val_loss: 0.0764
# Epoch 30/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0751 - val_loss: 0.0761
# Epoch 31/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0749 - val_loss: 0.0761
# Epoch 32/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0749 - val_loss: 0.0761
# Epoch 33/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0748 - val_loss: 0.0760
# Epoch 34/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0747 - val_loss: 0.0759
# Epoch 35/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0746 - val_loss: 0.0759
# Epoch 36/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0745 - val_loss: 0.0759
# Epoch 37/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0744 - val_loss: 0.0758
# Epoch 38/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0744 - val_loss: 0.0758
# Epoch 39/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0743 - val_loss: 0.0758
# Epoch 40/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0743 - val_loss: 0.0759
# Epoch 41/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0743 - val_loss: 0.0758
# Epoch 42/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0742 - val_loss: 0.0758
# Epoch 43/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0742 - val_loss: 0.0758
# Epoch 44/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0742 - val_loss: 0.0759
# Epoch 45/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0742 - val_loss: 0.0758
# Epoch 46/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0741 - val_loss: 0.0758
# Epoch 47/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0741 - val_loss: 0.0760
# Epoch 48/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0742 - val_loss: 0.0759
# Epoch 49/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0742 - val_loss: 0.0758
# Epoch 50/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0741 - val_loss: 0.0758
# Epoch 51/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0740 - val_loss: 0.0760
# Epoch 52/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0740 - val_loss: 0.0758
# Epoch 53/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0741 - val_loss: 0.0758
# Epoch 54/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0740 - val_loss: 0.0760
# Epoch 55/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0740 - val_loss: 0.0758
# Epoch 56/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0740 - val_loss: 0.0757
# Epoch 57/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0739 - val_loss: 0.0758
# Epoch 58/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0739 - val_loss: 0.0758
# Epoch 59/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0738 - val_loss: 0.0757
# Epoch 60/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0738 - val_loss: 0.0757

# %%
# Generate Restored Images from the x_test using the autoencoder predict function
reconstructed_images = autoencoder.predict(x_test)

# Display Images
display_digits(x_test, reconstructed_images, digits=10)
# Out:
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step

# %% [markdown]
# ## Convolutional AutoEncoder
#
# Lets add some convolutions to our networks

# %% [markdown]
# First we need to reshape our data to 2D Matrix style

# %%
# Change the data from 1D 3600 to a 2D 60x60 shape
x_train_cnn = np.reshape(x_train, (len(x_train), 60, 60, 1))

x_test_cnn = np.reshape(x_test, (len(x_test), 60, 60, 1))

# %% [markdown]
# Build the Network

# %%
# Set the bottleneck size to be 81.
bottleneck_size = 81

# This is our input image
input_img = keras.Input(shape=(60, 60, 1))

# Define the Encoder
x = layers.Conv2D(40, (3, 3), activation='relu', padding='same')(input_img)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(20, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Flatten()(x)
encoded = layers.Dense(bottleneck_size)(x)

# Define the decoder
x = layers.BatchNormalization()(x)
x = layers.Reshape((9, 9, 1))(encoded)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(20, (3, 3), activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(40, (3, 3), activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

# The model take the image and feeds it to the 'input_img' layer and then process it and output it from the 'decoded' layer
autoencoder = keras.Model(input_img, decoded)


# Compile the autoencoder using 'adam' as the optimizer and the 'binary_crossentropy' loss.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Print the summary of the autoencoder.
autoencoder.summary()

# Visualize the model
visualkeras.layered_view(autoencoder, legend=True,  draw_volume=True, spacing= 10, color_map= color_map)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 60, 60, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 60, 60, 40)          │             400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 60, 60, 40)          │             160 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 30, 30, 40)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 30, 30, 20)          │           7,220 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 30, 30, 20)          │              80 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 15, 15, 20)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 15, 15, 8)           │           1,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 15, 15, 8)           │              32 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 8, 8, 8)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 81)                  │          41,553 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 9, 9, 1)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 9, 9, 8)             │              80 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 9, 9, 8)             │              32 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d (UpSampling2D)         │ (None, 18, 18, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 16, 16, 20)          │           1,460 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 16, 16, 20)          │              80 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_1 (UpSampling2D)       │ (None, 32, 32, 20)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 30, 30, 40)          │           7,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 30, 30, 40)          │             160 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_2 (UpSampling2D)       │ (None, 60, 60, 40)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 60, 60, 1)           │             361 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 60,306 (235.57 KB)
#  Trainable params: 60,034 (234.51 KB)
#  Non-trainable params: 272 (1.06 KB)
# <PIL.Image.Image image mode=RGBA size=812x386>

# %%
# Fit the autoencoder to the training data by setting epochs to 60 and batch size to 128.
autoencoder.fit(x_train_cnn, x_train_cnn,
                epochs=60, batch_size=128,
                shuffle=True,
                validation_data=(x_test_cnn, x_test_cnn))
# Out:
# Epoch 1/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 22s 103ms/step - loss: 0.5857 - val_loss: 0.2140
# Epoch 2/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.1227 - val_loss: 0.2407
# Epoch 3/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0988 - val_loss: 0.2448
# Epoch 4/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0920 - val_loss: 0.2339
# Epoch 5/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0883 - val_loss: 0.1779
# Epoch 6/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0859 - val_loss: 0.1119
# Epoch 7/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0841 - val_loss: 0.0871
# Epoch 8/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0828 - val_loss: 0.0834
# Epoch 9/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0818 - val_loss: 0.0846
# Epoch 10/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0809 - val_loss: 0.0841
# Epoch 11/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0801 - val_loss: 0.0841
# Epoch 12/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0795 - val_loss: 0.0829
# Epoch 13/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0789 - val_loss: 0.0815
# Epoch 14/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0784 - val_loss: 0.0822
# Epoch 15/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0779 - val_loss: 0.0812
# Epoch 16/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0775 - val_loss: 0.0803
# Epoch 17/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0772 - val_loss: 0.0798
# Epoch 18/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0768 - val_loss: 0.0785
# Epoch 19/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0765 - val_loss: 0.0788
# Epoch 20/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0762 - val_loss: 0.0802
# Epoch 21/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0760 - val_loss: 0.0788
# Epoch 22/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0757 - val_loss: 0.0806
# Epoch 23/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0755 - val_loss: 0.0784
# Epoch 24/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0753 - val_loss: 0.0791
# Epoch 25/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0751 - val_loss: 0.0811
# Epoch 26/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0749 - val_loss: 0.0795
# Epoch 27/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0748 - val_loss: 0.0773
# Epoch 28/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0746 - val_loss: 0.0785
# Epoch 29/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0744 - val_loss: 0.0790
# Epoch 30/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0743 - val_loss: 0.0783
# Epoch 31/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0742 - val_loss: 0.0790
# Epoch 32/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0740 - val_loss: 0.0782
# Epoch 33/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0739 - val_loss: 0.0778
# Epoch 34/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0738 - val_loss: 0.0779
# Epoch 35/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0737 - val_loss: 0.0771
# Epoch 36/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0736 - val_loss: 0.0777
# Epoch 37/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0734 - val_loss: 0.0767
# Epoch 38/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0733 - val_loss: 0.0760
# Epoch 39/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0732 - val_loss: 0.0758
# Epoch 40/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0731 - val_loss: 0.0756
# Epoch 41/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0730 - val_loss: 0.0744
# Epoch 42/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0729 - val_loss: 0.0751
# Epoch 43/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0728 - val_loss: 0.0748
# Epoch 44/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0727 - val_loss: 0.0746
# Epoch 45/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0727 - val_loss: 0.0746
# Epoch 46/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0726 - val_loss: 0.0748
# Epoch 47/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0725 - val_loss: 0.0753
# Epoch 48/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0725 - val_loss: 0.0740
# Epoch 49/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0724 - val_loss: 0.0741
# Epoch 50/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0723 - val_loss: 0.0747
# Epoch 51/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0723 - val_loss: 0.0751
# Epoch 52/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0723 - val_loss: 0.0759
# Epoch 53/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0723 - val_loss: 0.0767
# Epoch 54/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0724 - val_loss: 0.0745
# Epoch 55/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0723 - val_loss: 0.0739
# Epoch 56/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0723 - val_loss: 0.0739
# Epoch 57/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0722 - val_loss: 0.0737
# Epoch 58/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0721 - val_loss: 0.0739
# Epoch 59/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0720 - val_loss: 0.0742
# Epoch 60/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0719 - val_loss: 0.0732

# %%
# predict the reconstructed images using the autoencoder predict function and by feeding it with the x_test_cnn
decoded_imgs = autoencoder.predict(x_test_cnn)

# Visualize our results
display_digits(x_test_cnn, decoded_imgs, 10)
# Out:
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step

# %% [markdown]
# ## Deeper AutoEncoder

# %%
# Lets Create now a deeper Encoder Decoder Networks

# Set the bottleneck size to be 81.
bottleneck_size = 81

# Create the input layer having the shape of the training data input shape = 3600
input_layer = keras.layers.Input(shape=(3600,))

# Define the Encoder
# Hidden activations are 'relu' while last layer activation is 'sigmoid'

# Create the encoder having the first hidden layer with 1000 neurons
x = keras.layers.Dense(1000, activation='relu')(input_layer)
x = layers.BatchNormalization()(x)
# The second hidden layer having 300 neurons
x = keras.layers.Dense(300, activation='relu')(x)
# The third hidden layer having the bottleneck_size
encoded = keras.layers.Dense(bottleneck_size, activation='sigmoid')(x)

# Define the Decoder
# Create the first layer of the decoder having 300 neurons
x = keras.layers.Dense(300, activation='relu')(encoded)
x = layers.BatchNormalization()(x)
# Create the second layer of the decoder having 1000 neurons
x = keras.layers.Dense(1000, activation='relu')(x)
x = layers.BatchNormalization()(x)
# Create the third layer of the decoder having the input shape
decoded = keras.layers.Dense(3600, activation='sigmoid')(x)


# Create the autoencoder.
autoencoder = keras.models.Model(input_layer, decoded)

# Compile the autoencoder using 'adam' as the optimizer and the 'binary_crossentropy' loss.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Print the summary of the autoencoder.
autoencoder.summary()

# Visualize the model
visualkeras.layered_view(autoencoder, legend=True,  draw_volume=True, spacing= 10, color_map = color_map)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 3600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 1000)                │       3,601,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_11               │ (None, 1000)                │           4,000 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 300)                 │         300,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 81)                  │          24,381 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 300)                 │          24,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 300)                 │           1,200 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 1000)                │         301,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_13               │ (None, 1000)                │           4,000 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 3600)                │       3,603,600 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,864,081 (30.00 MB)
#  Trainable params: 7,859,481 (29.98 MB)
#  Non-trainable params: 4,600 (17.97 KB)
# <PIL.Image.Image image mode=RGBA size=1347x65>

# %%
# Fit the autoencoder to the x_train data and validate using the x_test by setting epochs to 60 and batch size to 128.
autoencoder.fit(x_train, x_train,
                epochs=60, batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test)
               )
# Out:
# Epoch 1/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - loss: 0.5552 - val_loss: 0.1372
# Epoch 2/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1008 - val_loss: 0.1040
# Epoch 3/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0902 - val_loss: 0.0905
# Epoch 4/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0850 - val_loss: 0.0864
# Epoch 5/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0828 - val_loss: 0.0880
# Epoch 6/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0814 - val_loss: 0.0837
# Epoch 7/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0793 - val_loss: 0.0820
# Epoch 8/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0778 - val_loss: 0.0800
# Epoch 9/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0768 - val_loss: 0.0807
# Epoch 10/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0761 - val_loss: 0.0799
# Epoch 11/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0753 - val_loss: 0.0775
# Epoch 12/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0743 - val_loss: 0.0767
# Epoch 13/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0735 - val_loss: 0.0760
# Epoch 14/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0726 - val_loss: 0.0765
# Epoch 15/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0723 - val_loss: 0.0760
# Epoch 16/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0722 - val_loss: 0.0766
# Epoch 17/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0723 - val_loss: 0.0759
# Epoch 18/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0720 - val_loss: 0.0747
# Epoch 19/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0714 - val_loss: 0.0748
# Epoch 20/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0706 - val_loss: 0.0742
# Epoch 21/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0700 - val_loss: 0.0747
# Epoch 22/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0698 - val_loss: 0.0742
# Epoch 23/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0698 - val_loss: 0.0747
# Epoch 24/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0699 - val_loss: 0.0745
# Epoch 25/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0698 - val_loss: 0.0743
# Epoch 26/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0696 - val_loss: 0.0743
# Epoch 27/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0693 - val_loss: 0.0734
# Epoch 28/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0688 - val_loss: 0.0737
# Epoch 29/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0687 - val_loss: 0.0738
# Epoch 30/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0684 - val_loss: 0.0737
# Epoch 31/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0683 - val_loss: 0.0730
# Epoch 32/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0681 - val_loss: 0.0729
# Epoch 33/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0680 - val_loss: 0.0729
# Epoch 34/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0678 - val_loss: 0.0727
# Epoch 35/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0676 - val_loss: 0.0726
# Epoch 36/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0674 - val_loss: 0.0729
# Epoch 37/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0674 - val_loss: 0.0733
# Epoch 38/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0675 - val_loss: 0.0732
# Epoch 39/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0675 - val_loss: 0.0734
# Epoch 40/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0675 - val_loss: 0.0733
# Epoch 41/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0675 - val_loss: 0.0734
# Epoch 42/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0674 - val_loss: 0.0735
# Epoch 43/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0677 - val_loss: 0.0731
# Epoch 44/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0676 - val_loss: 0.0729
# Epoch 45/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0673 - val_loss: 0.0727
# Epoch 46/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0671 - val_loss: 0.0728
# Epoch 47/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0669 - val_loss: 0.0724
# Epoch 48/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0667 - val_loss: 0.0724
# Epoch 49/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0667 - val_loss: 0.0723
# Epoch 50/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0667 - val_loss: 0.0723
# Epoch 51/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0666 - val_loss: 0.0725
# Epoch 52/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0666 - val_loss: 0.0724
# Epoch 53/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0664 - val_loss: 0.0727
# Epoch 54/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0665 - val_loss: 0.0727
# Epoch 55/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0666 - val_loss: 0.0722
# Epoch 56/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0665 - val_loss: 0.0723
# Epoch 57/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0665 - val_loss: 0.0722
# Epoch 58/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0665 - val_loss: 0.0721
# Epoch 59/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0663 - val_loss: 0.0724
# Epoch 60/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0662 - val_loss: 0.0724

# %%
# Generate restored images from x_test using the autoencoder predict function
reconstructed_images = autoencoder.predict(x_test)

# Display digits results, set the digits for the letters you want to visualize e.g. 10
display_digits(x_test, reconstructed_images, digits=10)
# Out:
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step

# %% [markdown]
# # Some Visualizations

# %% [markdown]
# Using the above trained model, we'll extract the encoder and decoder

# %%
# Define the Encoder Model taking input as the input_layer and output as the encoded layer
encoder_model = keras.Model(input_layer, encoded)

# Define the Decoder Model taking as input the encoded layer and output as the decoded layer
decoder_model = keras.Model(encoded, decoded)

# %%
# Let's visualize what happened
# Choose any image from the test test, e.g. index = 9
image = x_test[9]
print("Our image has {} parameters".format(image.shape[0]))
# Out:
# Our image has 3600 parameters

# %%
# Reshape to 60x60 and visualize it
plt.imshow(image.reshape(60,60), cmap='gray')

# %%
# Encode the image using the encoder_model using the predict function
encoded_image = encoder_model.predict(image.reshape(1, 3600))[0]
print("The encoded representation vector for that image contains now only {} parameters".format(encoded_image.shape[0]))
print("or only {} % of the original data".format(100*encoded_image.shape[0]/image.shape[0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# The encoded representation vector for that image contains now only 81 parameters
# or only 2.25 % of the original data

# %%
# Let's visualize the encoded_image
# Reshape the 81 vector to 9x9 to better visualize it
plt.imshow(encoded_image.reshape(9,9), cmap='gray')

# %%
# Now Using only the 9x9 vector let's try reconstructing the image

decoded_image = decoder_model.predict(encoded_image.reshape(1, 81))[0]

# Reshape to 60x60 and visualize it
plt.imshow(decoded_image.reshape(60, 60), cmap='gray')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step

# %%
# On a more scaled Plots for better visualizations with scale

fig, axes = plt.subplots(1, 3, figsize=(20, 4),sharex=False, sharey=True)
fig.suptitle('Original --> Compressed --> Reconstructed', fontsize=14, fontweight='bold', y=1.1)

axes = axes.flatten()
# Display original image.
axes[0].imshow(image.reshape(60,60), cmap='gray')
axes[0].axis('off')
axes[0].set_title('Original Image')
# Display latent representation of the image.
axes[1].imshow(encoded_image.reshape(9,9), cmap='gray')
axes[1].axis('off')
axes[1].set_title('Latent Representation')
# Display the reconstructed image
axes[2].imshow(decoded_image.reshape(60,60), cmap='gray')
axes[2].axis('off')
axes[2].set_title('Reconstructed Image')
plt.show()

# %%
# Let's try playing with some pixels in the encoded image
encoded_image_pixel_changed = encoded_image.copy()

# Reshape the vector to 9x9
encoded_image_pixel_changed = encoded_image_pixel_changed.reshape(9, 9)

# From the above 9x9 encoded image - latent Representation - choose any pixel that appears to be white colored ==> high value and let's try setting it to 0
# Fill in the xy coordinates of that image using the previous encoded_image plot and set its value to 0
encoded_image_pixel_changed[4][5] = 0

# Reshape the 81 vector to 9x9 to better visualize it
plt.imshow(encoded_image_pixel_changed.reshape(9,9), cmap='gray')

# %%
# Now Using only the edited 9x9 vector let's reconstruct the decoded image using the decoder_model

decoded_image = decoder_model.predict(encoded_image_pixel_changed.reshape(1, 81))[0]

plt.imshow(decoded_image.reshape(60,60), cmap='gray')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %% [markdown]
# # An Application on AutoEncoder

# %% [markdown]
# ## Feature Extractor
#
# Let's Try making use of the power of autoencoder in learning latent representations to build a classifer

# %%
# Load our dataset labels
y_train = dataset['y_train'][0]
y_test = dataset['y_test'][0]
labels = ['٠', '١', '٢', '٣', '٤', '٥', '٦', '٧', '٨', '٩', 'أ', 'ب', 'ت', 'ث', 'ج', 'ح', 'خ', 'د', 'ذ', 'ر', 'ز', 'س', 'ش', 'ص', 'ض', 'ط', 'ظ', 'ع', 'غ', 'ف', 'ق', 'ك', 'ل', 'م', 'ن', 'ه', 'و', 'ى']
y_test.shape, y_test.shape
# Out:
# ((3359,), (3359,))

# %%
# Let's visualize the dataset of images with their corresponding labels
# Get a sample of 25 random images from the training noisy dataset.
indexes = random.sample(range(len(x_train)), 25)

sample_images = x_train[indexes]
sample_targets = y_train[indexes]
# Display the images.
plt.figure(figsize=(10,10))
# Set a title for the figure.
plt.suptitle('Random Images from the Training with Labels Dataset', fontsize=24, fontweight='bold')

for i in range(25):
    # Set the place holder to the current image.
    plt.subplot(5, 5, i+1)
    # Display the current image.
    plt.title(labels[sample_targets[i]])
    plt.imshow(sample_images[i].reshape(60, 60), cmap='gray')
    plt.axis('off')

# %% [markdown]
# Now we'll try training a classifier using only the latent representations learned from our encoder in the Deeper AutoEncoder task inorder to classify our letters

# %%
# Output neurons are set to the length of labels list
output_neurons = len(labels)

# Define our input layer having 3600 as input
input_img = keras.Input(shape=(3600,))

# Use the encoder_model to encode the input_image
encoded_img = encoder_model(input_img)

# Set the encoder_model as nontrainable, we're not interested in training them anymore. We are taking only the learned latent representation
# Set the trainable parameter of encoder_model to False
encoder_model.trainable = False

# Create BatchNormalization layer
x = layers.BatchNormalization()(encoded_img)

# Create first dense layer with 512 neurons and a relu activation function
x = layers.Dense(512, activation='relu')(x)

# Create BatchNormalization layer
x = layers.BatchNormalization()(x)

# Create our output layer having output neurons equal to the output_neurons parameter and the suitable activation function for our multiclass classification task
classifier_output = layers.Dense(output_neurons, activation='softmax')(x)

# Create the classifier taken input_image as first layer and classifier_output as output layer
classifier_model = keras.Model(input_img, classifier_output)

# Print our model summary
classifier_model.summary()

# Compile the clasisifer using 'sparse_categorical_crossentropy' as a loss function, 'accuracy' as a metric and the same optimizer as in above examples
classifier_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)           │ (None, 3600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ functional_3 (Functional)            │ (None, 81)                  │       3,929,681 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_14               │ (None, 81)                  │             324 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 512)                 │          41,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_15               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 38)                  │          19,494 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,993,531 (15.23 MB)
#  Trainable params: 62,664 (244.78 KB)
#  Non-trainable params: 3,930,867 (15.00 MB)

# %%
# Fit the classifier_model to the training data (x_train, y_train) while validating using (x_test, y_test) and by setting epochs to 30 and batch size to 128.
classifier_model.fit(x_train, y_train,
                     epochs=30, batch_size=128,
                     shuffle=True,
                     validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.2528 - loss: 2.9284 - val_accuracy: 0.3141 - val_loss: 2.8600
# Epoch 2/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5812 - loss: 1.4182 - val_accuracy: 0.4981 - val_loss: 2.0209
# Epoch 3/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6905 - loss: 1.0499 - val_accuracy: 0.6332 - val_loss: 1.3616
# Epoch 4/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7705 - loss: 0.8183 - val_accuracy: 0.6913 - val_loss: 1.0404
# Epoch 5/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8225 - loss: 0.6569 - val_accuracy: 0.7216 - val_loss: 0.9105
# Epoch 6/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8642 - loss: 0.5357 - val_accuracy: 0.7336 - val_loss: 0.8492
# Epoch 7/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8935 - loss: 0.4402 - val_accuracy: 0.7407 - val_loss: 0.8145
# Epoch 8/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9253 - loss: 0.3622 - val_accuracy: 0.7496 - val_loss: 0.7945
# Epoch 9/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9443 - loss: 0.2983 - val_accuracy: 0.7520 - val_loss: 0.7849
# Epoch 10/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9619 - loss: 0.2446 - val_accuracy: 0.7550 - val_loss: 0.7784
# Epoch 11/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9746 - loss: 0.2003 - val_accuracy: 0.7609 - val_loss: 0.7772
# Epoch 12/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9855 - loss: 0.1633 - val_accuracy: 0.7633 - val_loss: 0.7786
# Epoch 13/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9917 - loss: 0.1333 - val_accuracy: 0.7651 - val_loss: 0.7818
# Epoch 14/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9961 - loss: 0.1088 - val_accuracy: 0.7669 - val_loss: 0.7881
# Epoch 15/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9975 - loss: 0.0888 - val_accuracy: 0.7684 - val_loss: 0.7938
# Epoch 16/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9987 - loss: 0.0729 - val_accuracy: 0.7696 - val_loss: 0.8026
# Epoch 17/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9994 - loss: 0.0602 - val_accuracy: 0.7699 - val_loss: 0.8111
# Epoch 18/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9996 - loss: 0.0502 - val_accuracy: 0.7711 - val_loss: 0.8200
# Epoch 19/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0422 - val_accuracy: 0.7731 - val_loss: 0.8291
# Epoch 20/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0358 - val_accuracy: 0.7717 - val_loss: 0.8386
# Epoch 21/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0307 - val_accuracy: 0.7728 - val_loss: 0.8474
# Epoch 22/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 0.7737 - val_loss: 0.8558
# Epoch 23/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0231 - val_accuracy: 0.7743 - val_loss: 0.8642
# Epoch 24/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0202 - val_accuracy: 0.7726 - val_loss: 0.8733
# Epoch 25/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0178 - val_accuracy: 0.7726 - val_loss: 0.8813
# Epoch 26/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.7731 - val_loss: 0.8895
# Epoch 27/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.7728 - val_loss: 0.8982
# Epoch 28/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.7714 - val_loss: 0.9057
# Epoch 29/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.7737 - val_loss: 0.9135
# Epoch 30/30
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.7723 - val_loss: 0.9209

# %%
# Let's visualize some predictions
# Get a sample of 25 random images from the training dataset.
indexes = random.sample(range(len(x_test)), 25)

sample_images = x_test[indexes]
# Display the images.
plt.figure(figsize=(10,15))
# Set a title for the figure.
plt.suptitle('Predictions on Some Images from TestSet', fontsize=24, fontweight='bold')

for i in range(25):
    # Set the place holder to the current image.
    plt.subplot(5, 5, i+1)
    # Reshape the sample_image to (1,3600) to be fed to our model
    sample_image = sample_images[i].reshape(1, 3600)
    # Get the predictions of the sample_image using our classifier_model predict function
    predicted_labels_weights = classifier_model.predict(sample_image)
    # Get the highest weighted predicted label using the argmax() function
    predicted_label = predicted_labels_weights.argmax()
    # Get the predicted character from the predicted_label using our labels list
    character_label = labels[predicted_label]
    # Display the title as our predicted label
    plt.title(character_label, fontdict={'fontsize':24}, pad=10)
    # Display the current image and reshape to 60x60
    plt.imshow(sample_images[i].reshape(60, 60), cmap='gray')
    plt.axis('off')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %% [markdown]
# ## Noise Filtering

# %%
# Create some noise for the training data
train_noise = np.random.normal(0, 0.1, x_train.shape)

# Create some noise for the testing data
test_noise = np.random.normal(0, 0.1, x_test.shape)

# %%
# Visualize one of the noise filters that we'll add to our training dataset
plt.imshow(train_noise[0].reshape(60,60), cmap='gray')

# %%
# Add the noise filters to our training and testing datasets
x_train_noisy =  x_train + train_noise
x_test_noisy = x_test + test_noise

# %%
# Let's visualize the noisy dataset
# Get a sample of 25 random images from the training noisy dataset.
sample_images = random.sample(list(x_train_noisy), 25)
# Display the images.
plt.figure(figsize=(10,10))
# Set a title for the figure.
plt.suptitle('Random Images from the Training Noisy Dataset', fontsize=24, fontweight='bold')

for i in range(25):
    # Set the place holder to the current image.
    plt.subplot(5, 5, i+1)
    # Display the current image.
    plt.imshow(sample_images[i].reshape(60, 60), cmap='gray')
    plt.axis('off')

# %%
# Lets Create now a deeper Encoder Decoder Networks

# Set the bottleneck size to be 81.
bottleneck_size = 81

# Create the input layer having the shape of the training data input shape = 3600
input_layer = keras.layers.Input(shape=(3600,))

# Create the encoder having the first hidden layer with 1000 neurons and actuvation to relu
x = keras.layers.Dense(1000, activation='relu')(input_layer)
# Add a BacthNormalization layer
x = keras.layers.BatchNormalization()(x)
# The second hidden layer having 300 neurons
x = keras.layers.Dense(300, activation='relu')(x)

# The third hidden layer having the bottleneck_size
encoded = keras.layers.Dense(bottleneck_size, activation='relu')(x)

# Create the first layer of the decoder having 300 neurons
x = keras.layers.Dense(300, activation='relu')(encoded)
# Add BatchNormalization layer
x = keras.layers.BatchNormalization()(x)
# Create the second layer of the decoder having 1000 neurons
x = keras.layers.Dense(1000, activation='relu')(x)
# Add BatchNormalization layer
x = keras.layers.BatchNormalization()(x)
# Create the third layer of the decoder having the input shape
decoded = keras.layers.Dense(3600, activation='sigmoid')(x)


# Create the autoencoder.
autoencoder = keras.models.Model(input_layer, decoded)

# Compile the autoencoder using 'adam' as the optimizer and the 'binary_crossentropy' loss.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')


# Print the summary of the autoencoder.
autoencoder.summary()


# Visualize the model
visualkeras.layered_view(autoencoder, legend=True,  draw_volume=True, spacing= 10, color_map = color_map)
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)           │ (None, 3600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 1000)                │       3,601,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_19               │ (None, 1000)                │           4,000 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 300)                 │         300,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (None, 81)                  │          24,381 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 300)                 │          24,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_20               │ (None, 300)                 │           1,200 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 1000)                │         301,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_21               │ (None, 1000)                │           4,000 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 3600)                │       3,603,600 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,864,081 (30.00 MB)
#  Trainable params: 7,859,481 (29.98 MB)
#  Non-trainable params: 4,600 (17.97 KB)
# <PIL.Image.Image image mode=RGBA size=1347x65>

# %%
# Fit the autoencoder to the training data where our input is now the noise one (x_train_noisy)
# and the output we are trying to learn is the clean one (x_train)
# The same gos for the validation
# Set epochs to 60 and batch size to 128.

autoencoder.fit(
    x_train_noisy, x_train,
    epochs=60,
    batch_size=128,
    validation_data=(x_test_noisy, x_test)
)
# Out:
# Epoch 1/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - loss: 0.5614 - val_loss: 0.1205
# Epoch 2/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1039 - val_loss: 0.0981
# Epoch 3/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0916 - val_loss: 0.0954
# Epoch 4/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0862 - val_loss: 0.0850
# Epoch 5/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0829 - val_loss: 0.0850
# Epoch 6/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0817 - val_loss: 0.0909
# Epoch 7/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0799 - val_loss: 0.0891
# Epoch 8/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0776 - val_loss: 0.0808
# Epoch 9/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0761 - val_loss: 0.0790
# Epoch 10/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0753 - val_loss: 0.0805
# Epoch 11/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0750 - val_loss: 0.0809
# Epoch 12/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0742 - val_loss: 0.0822
# Epoch 13/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0740 - val_loss: 0.0812
# Epoch 14/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0732 - val_loss: 0.0786
# Epoch 15/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0723 - val_loss: 0.0776
# Epoch 16/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0721 - val_loss: 0.0784
# Epoch 17/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0717 - val_loss: 0.0779
# Epoch 18/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0715 - val_loss: 0.0779
# Epoch 19/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0711 - val_loss: 0.0786
# Epoch 20/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0708 - val_loss: 0.0782
# Epoch 21/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0703 - val_loss: 0.0763
# Epoch 22/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0699 - val_loss: 0.0767
# Epoch 23/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0699 - val_loss: 0.0778
# Epoch 24/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0698 - val_loss: 0.0784
# Epoch 25/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0697 - val_loss: 0.0780
# Epoch 26/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0694 - val_loss: 0.0770
# Epoch 27/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0692 - val_loss: 0.0769
# Epoch 28/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0690 - val_loss: 0.0771
# Epoch 29/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0688 - val_loss: 0.0762
# Epoch 30/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0686 - val_loss: 0.0761
# Epoch 31/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0685 - val_loss: 0.0756
# Epoch 32/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0682 - val_loss: 0.0761
# Epoch 33/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0680 - val_loss: 0.0761
# Epoch 34/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0681 - val_loss: 0.0759
# Epoch 35/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0681 - val_loss: 0.0767
# Epoch 36/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0681 - val_loss: 0.0769
# Epoch 37/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0683 - val_loss: 0.0774
# Epoch 38/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0684 - val_loss: 0.0773
# Epoch 39/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0681 - val_loss: 0.0766
# Epoch 40/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0678 - val_loss: 0.0765
# Epoch 41/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0675 - val_loss: 0.0762
# Epoch 42/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0672 - val_loss: 0.0764
# Epoch 43/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0673 - val_loss: 0.0762
# Epoch 44/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0675 - val_loss: 0.0766
# Epoch 45/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0675 - val_loss: 0.0767
# Epoch 46/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0676 - val_loss: 0.0770
# Epoch 47/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0676 - val_loss: 0.0767
# Epoch 48/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0677 - val_loss: 0.0758
# Epoch 49/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0676 - val_loss: 0.0766
# Epoch 50/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0674 - val_loss: 0.0769
# Epoch 51/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0674 - val_loss: 0.0763
# Epoch 52/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0674 - val_loss: 0.0759
# Epoch 53/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0672 - val_loss: 0.0759
# Epoch 54/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0669 - val_loss: 0.0761
# Epoch 55/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0667 - val_loss: 0.0760
# Epoch 56/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0666 - val_loss: 0.0754
# Epoch 57/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0666 - val_loss: 0.0752
# Epoch 58/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0665 - val_loss: 0.0753
# Epoch 59/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0664 - val_loss: 0.0756
# Epoch 60/60
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0663 - val_loss: 0.0756

# %% [markdown]
# Let's visualize how the autoencoder is doing at cleaning the noise from the letters

# %%
# Generate Restored Images from the x_test_noisy using the autoencoder predict function
reconstructed_images = autoencoder.predict(x_test_noisy)

# Display Images
display_digits(x_test_noisy, reconstructed_images, digits=10)
# Out:
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
